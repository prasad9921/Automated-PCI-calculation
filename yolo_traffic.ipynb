# %%
import cv2

# %%
import cvlib as cv

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox
im = cv2.imread('car4.jpeg')
bbox, label, conf = cv.detect_common_objects(im)

output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()
print('Number of cars in the image is '+ str(label.count('car')))
print('Number of buses in the image is '+ str(label.count('bus')))
print('Number of trucks in the image is '+ str(label.count('truck')))
print('Number of motorcycle in the image is '+ str(label.count('motorcycle')))

s=(label.count('car')/10)+(label.count('bus')/10)+(label.count('truck')/10)+(label.count('motorcycle')/10)
print('Traffic density in the image is '+str(s))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-7ac507919b4d> in <module>
#       4 from cvlib.object_detection import draw_bbox
#       5 im = cv2.imread('car4.jpeg')
# ----> 6 bbox, label, conf = cv.detect_common_objects(im)
#       7
#       8 output_image = draw_bbox(im, bbox, label, conf)
#
# ~/anaconda3/lib/python3.7/site-packages/cvlib/object_detection.py in detect_common_objects(image, confidence, nms_thresh, model, enable_gpu)
#      58 def detect_common_objects(image, confidence=0.5, nms_thresh=0.3, model='yolov3', enable_gpu=False):
#      59
# ---> 60     Height, Width = image.shape[:2]
#      61     scale = 0.00392
#      62
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
import xlwt 
from xlwt import Workbook 
from cvlib.object_detection import draw_bbox
im = cv2.imread('car4.jpeg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()
print('Number of cars in the image is '+ str(label.count('car')))
print('Number of buses in the image is '+ str(label.count('bus')))
print('Number of trucks in the image is '+ str(label.count('truck')))
print('Number of motorcycle in the image is '+ str(label.count('motorcycle')))

s=(label.count('car')/10)+(label.count('bus')/10)+(label.count('truck')/10)+(label.count('motorcycle')/10)
print('Traffic density in the image is '+str(s))
wb = Workbook()  
sheet1 = wb.add_sheet('Sheet 1') 
sheet1.write(0,0,str(label.count('car')/10))
im = cv2.imread('traffic.jpg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()
s=0
print('Number of cars in the image is '+ str(label.count('car')))
print('Number of buses in the image is '+ str(label.count('bus')))
print('Number of trucks in the image is '+ str(label.count('truck')))
print('Number of motorcycles in the image is '+ str(label.count('motorcycle')))

s=(label.count('car')/10)+(label.count('bus')/10)+(label.count('truck')/10)+(label.count('motorcycle')/10)
print('Traffic density in the image is '+str(round(s,2)))
sheet1.write(1,0,str(s))
# Out:
# Number of cars in the image is 22
# Number of buses in the image is 0
# Number of trucks in the image is 0
# Number of motorcycle in the image is 1
# Traffic density in the image is 2.3000000000000003
# Number of cars in the image is 43
# Number of buses in the image is 0
# Number of trucks in the image is 0
# Number of motorcycles in the image is 0
# Traffic density in the image is 4.3

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
import xlwt 
from xlwt import Workbook 
from cvlib.object_detection import draw_bbox
im = cv2.imread('1.jpg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()
s=0
print('Number of cars in the image is '+ str(label.count('car')))
print('Number of buses in the image is '+ str(label.count('bus')))
print('Number of trucks in the image is '+ str(label.count('truck')))
print('Number of motorcycles in the image is '+ str(label.count('motorcycle')))

s=(label.count('car')/10)+(label.count('bus')/10)+(label.count('truck')/10)+(label.count('motorcycle')/10)
print('Traffic density in the image is '+str(s))
sheet1.write(2,0,str(s))

im = cv2.imread('2.jpg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()
print('Number of cars in the image is '+ str(label.count('car')))
print('Number of buses in the image is '+ str(label.count('bus')))
print('Number of trucks in the image is '+ str(label.count('truck')))
print('Number of motorcycles in the image is '+ str(label.count('motorcycle')))

s=(label.count('car')/10)+(label.count('bus')/10)+(label.count('truck')/10)+(label.count('motorcycle')/10)
print('Traffic density in the image is '+str(s))
sheet1.write(3,0,str(label.count('car')/10))

im = cv2.imread('3.jpg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()
print('Number of cars in the image is '+ str(label.count('car')))
print('Number of buses in the image is '+ str(label.count('bus')))
print('Number of trucks in the image is '+ str(label.count('truck')))
print('Number of motorcycles in the image is '+ str(label.count('motorcycle')))

s=(label.count('car')/10)+(label.count('bus')/10)+(label.count('truck')/10)+(label.count('motorcycle')/10)
print('Traffic density in the image is '+str(s))
sheet1.write(4,0,str(label.count('car')/10))
im = cv2.imread('traffic1.jpg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()
print('Number of cars in the image is '+ str(label.count('car')))
print('Number of buses in the image is '+ str(label.count('bus')))
print('Number of trucks in the image is '+ str(label.count('truck')))
print('Number of motorcycles in the image is '+ str(label.count('motorcycle')))

s=(label.count('car')/10)+(label.count('bus')/10)+(label.count('truck')/10)+(label.count('motorcycle')/10)
print('Traffic density in the image is '+str(s))
wb.save('xlwt example.xls')
# Out:
# Number of cars in the image is 7
# Number of buses in the image is 1
# Number of trucks in the image is 0
# Number of motorcycles in the image is 0
# Traffic density in the image is 0.7999999999999999
# Number of cars in the image is 12
# Number of buses in the image is 1
# Number of trucks in the image is 0
# Number of motorcycles in the image is 0
# Traffic density in the image is 1.3
# Number of cars in the image is 14
# Number of buses in the image is 0
# Number of trucks in the image is 1
# Number of motorcycles in the image is 0
# Traffic density in the image is 1.5
# Number of cars in the image is 5
# Number of buses in the image is 0
# Number of trucks in the image is 0
# Number of motorcycles in the image is 0
# Traffic density in the image is 0.5

# %%
from sklearn.metrics import accuracy_score

>>> accuracy_score()
0.5
>>> accuracy_score(y_true, y_pred, normalize=False)
2
# Out:
#   File "<ipython-input-14-fd3666af014c>", line 3
#     >>> accuracy_score()
#      ^
# SyntaxError: invalid syntax

# %%
pip install cvlib
# Out:
# ...
#      |████████████████████████████████| 10.0 MB 12.6 MB/s eta 0:00:01
# ...
#   Created wheel for cvlib: filename=cvlib-0.2.4-py3-none-any.whl size=10043765 sha256=2bfb55b04c5152ee41c146b2efb373c30d1e7bba7d7684fed969435b3d14c9a7
#   Stored in directory: /home/izaya/.cache/pip/wheels/03/07/b4/7b1b9e123021aa2a6ea08893add88dafc9e53c1ecf4f34a2ad
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12074 sha256=b33f5cbdcb96f1a6eadb7194f3291cbf7f6a930f887e42779624d8ab8cda4d80
#   Stored in directory: /home/izaya/.cache/pip/wheels/f0/fd/1f/3e35ed57e94cd8ced38dd46771f1f0f94f65fec548659ed855
# ...
#   Created wheel for imutils: filename=imutils-0.5.3-py3-none-any.whl size=25851 sha256=78b7eb0737b85735dc71f2ad41d98f62f3b3e938d6f56191d2c1cbb42790ae2c
#   Stored in directory: /home/izaya/.cache/pip/wheels/fc/9c/6d/1826267c72afa51b564c9c6e0f66abc806879338bc593a2270
# Successfully built cvlib progressbar imutils
# ...
# Note: you may need to restart the kernel to use updated packages.
